# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
from sklearn.preprocessing import StandardScaler

# %%
df_train = pd.read_csv('E:/Kaggle/Titanic/titanic_data/train.csv')
df_test = pd.read_csv('E:/Kaggle/Titanic/titanic_data/test.csv')

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
# PassengerId    418 non-null int64
# Pclass         418 non-null int64
# Name           418 non-null object
# Sex            418 non-null object
# Age            332 non-null float64
# SibSp          418 non-null int64
# Parch          418 non-null int64
# Ticket         418 non-null object
# Fare           417 non-null float64
# Cabin          91 non-null object
# Embarked       418 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %%
df_train.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
op_train = pd.read_csv('E:/Kaggle/Titanic/titanic_data/train.csv')
op_test = pd.read_csv('E:/Kaggle/Titanic/titanic_data/test.csv')
op_test['Survived'] = -1
#op = op_train.append(op_test)

# %%
op = op_train.append(op_test)
# Out:
# C:\Users\naive\Anaconda3\lib\site-packages\pandas\core\frame.py:6211: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)

# %%
op.head(20)
# Out:
#      Age Cabin Embarked     Fare  \
# 0   22.0   NaN        S   7.2500
# 1   38.0   C85        C  71.2833
# 2   26.0   NaN        S   7.9250
# 3   35.0  C123        S  53.1000
# 4   35.0   NaN        S   8.0500
# 5    NaN   NaN        Q   8.4583
# 6   54.0   E46        S  51.8625
# 7    2.0   NaN        S  21.0750
# 8   27.0   NaN        S  11.1333
# 9   14.0   NaN        C  30.0708
# 10   4.0    G6        S  16.7000
# 11  58.0  C103        S  26.5500
# 12  20.0   NaN        S   8.0500
# 13  39.0   NaN        S  31.2750
# 14  14.0   NaN        S   7.8542
# 15  55.0   NaN        S  16.0000
# 16   2.0   NaN        Q  29.1250
# 17   NaN   NaN        S  13.0000
# 18  31.0   NaN        S  18.0000
# 19   NaN   NaN        C   7.2250
#
#                                                  Name  Parch  PassengerId  \
# 0                             Braund, Mr. Owen Harris      0            1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# ...

# %%
op[op['Pclass'].values == 1].head()
# Out:
#      Age Cabin Embarked     Fare  \
# 1   38.0   C85        C  71.2833
# 3   35.0  C123        S  53.1000
# 6   54.0   E46        S  51.8625
# 11  58.0  C103        S  26.5500
# 23  28.0    A6        S  35.5000
#
#                                                  Name  Parch  PassengerId  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 6                             McCarthy, Mr. Timothy J      0            7
# 11                           Bonnell, Miss. Elizabeth      0           12
# 23                       Sloper, Mr. William Thompson      0           24
#
#     Pclass     Sex  SibSp  Survived    Ticket
# 1        1  female      1         1  PC 17599
# 3        1  female      1         1    113803
# 6        1    male      0         0     17463
# 11       1  female      0         1    113783
# 23       1    male      0         1    113788

# %%
op.loc[61, 'Embarked'] = "S"

# %%
op.loc[829, 'Embarked'] = 'S'

# %%
op[op['Name'] == 'Braund, Mr. Owen Harris']
# Out:
#     Age Cabin Embarked  Fare                     Name  Parch  PassengerId  \
# 0  22.0   NaN        S  7.25  Braund, Mr. Owen Harris      0            1
#
#    Pclass   Sex  SibSp  Survived     Ticket
# 0       3  male      1         0  A/5 21171

# %%
len(op)
# Out:
# 1309

# %%
op['Cabin'][op.Cabin.isnull()] = 'U0'
# Out:
# C:\Users\naive\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
op['Cabin_letter'] = op['Cabin'].apply(lambda x : re.search(r'([A-Za-z]+)', x).group())

# %%
op['Cabin_letter'] = pd.factorize(op['Cabin_letter'])[0]

# %%
op.head(10)
# Out:
#     Age Cabin Embarked     Fare  \
# 0  22.0    U0        S   7.2500
# 1  38.0   C85        C  71.2833
# 2  26.0    U0        S   7.9250
# 3  35.0  C123        S  53.1000
# 4  35.0    U0        S   8.0500
# 5   NaN    U0        Q   8.4583
# 6  54.0   E46        S  51.8625
# 7   2.0    U0        S  21.0750
# 8  27.0    U0        S  11.1333
# 9  14.0    U0        C  30.0708
#
#                                                 Name  Parch  PassengerId  \
# 0                            Braund, Mr. Owen Harris      0            1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...      0            2
# 2                             Heikkinen, Miss. Laina      0            3
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)      0            4
# 4                           Allen, Mr. William Henry      0            5
# 5                                   Moran, Mr. James      0            6
# 6                            McCarthy, Mr. Timothy J      0            7
# ...

# %%
len(op)
# Out:
# 1309

# %%
op['Title'] = op['Name'].str.extract('([A-Za-z]+)\.')

# %%
op['Title'].value_counts()
# Out:
# Mr          757
# Miss        260
# Mrs         197
# Master       61
# Rev           8
# Dr            8
# Col           4
# Major         2
# Ms            2
# Mlle          2
# Jonkheer      1
# Lady          1
# Countess      1
# Sir           1
# Don           1
# Mme           1
# Capt          1
# Dona          1
# Name: Title, dtype: int64

# %%
title_dict = {}

title_dict.update(dict.fromkeys(['Capt', 'Col', 'Major', 'Dr', 'Rev'], 'Officer'))
title_dict.update(dict.fromkeys(['Don', 'Sir', 'Countess','Dona', 'Lady'], 'Royalty'))
title_dict.update(dict.fromkeys(['Mme', 'Ms', 'Mrs'], 'Mrs'))
title_dict.update(dict.fromkeys(['Mr'], 'Mr'))
title_dict.update(dict.fromkeys(['Mlle', 'Miss'], 'Miss'))
title_dict.update(dict.fromkeys(['Master','Jonkheer'], 'Master'))
op['title'] = op['Title'].map(title_dict)

# %%
op['title'].value_counts()
# Out:
# Mr         757
# Miss       262
# Mrs        200
# Master      62
# Officer     23
# Royalty      5
# Name: title, dtype: int64

# %%
op['title'] = pd.factorize(op['title'])[0]

# %%
op['title'].value_counts()
# Out:
# 0    757
# 2    262
# 1    200
# 3     62
# 5     23
# 4      5
# Name: title, dtype: int64

# %%
len(op)
# Out:
# 1309

# %%
def gender_judge(x):
    if x == 'male':
        return 1
    elif x == 'female':
        return 0
    else:
        return None

# %%
op['sex'] = op['Sex'].apply(lambda x : gender_judge(x))

# %%
op.drop('Sex',axis=1,inplace=True)

# %%
op.drop('Cabin', axis=1, inplace=True)

# %%
op['total_family'] = op['Parch'] + op['SibSp']

# %%
op.head(5)
# Out:
#     Age Embarked     Fare                                               Name  \
# 0  22.0        S   7.2500                            Braund, Mr. Owen Harris
# 1  38.0        C  71.2833  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  26.0        S   7.9250                             Heikkinen, Miss. Laina
# 3  35.0        S  53.1000       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4  35.0        S   8.0500                           Allen, Mr. William Henry
#
#    Parch  PassengerId  Pclass  SibSp  Survived            Ticket  \
# 0      0            1       3      1         0         A/5 21171
# 1      0            2       1      1         1          PC 17599
# 2      0            3       3      0         1  STON/O2. 3101282
# 3      0            4       1      1         1            113803
# 4      0            5       3      0         0            373450
#
#    Cabin_letter Title  title  sex  total_family
# 0             0    Mr      0    1             1
# ...

# %%
len(op)
# Out:
# 1309

# %%
op_copy = op

# %%
op['Surnanme'] = op['Name'].apply(lambda x : x.split(',')[0].strip())

# %%
surname_dict = {}
surname_dict = op['Surnanme'].value_counts()
op['SurnameNum'] = op['Surnanme'].map(surname_dict)

# %%
op.head(20)
# Out:
#      Age     Fare  Parch  Pclass  SibSp  Survived  Cabin_letter  title  sex  \
# 0   22.0   7.2500      0       3      1         0             0      0    1
# 1   38.0  71.2833      0       1      1         1             1      1    0
# 2   26.0   7.9250      0       3      0         1             0      2    0
# 3   35.0  53.1000      0       1      1         1             1      1    0
# 4   35.0   8.0500      0       3      0         0             0      0    1
# 5    NaN   8.4583      0       3      0         0             0      0    1
# 6   54.0  51.8625      0       1      0         0             2      0    1
# 7    2.0  21.0750      1       3      3         0             0      3    1
# 8   27.0  11.1333      2       3      0         1             0      1    0
# 9   14.0  30.0708      0       2      1         1             0      1    0
# 10   4.0  16.7000      1       3      1         1             3      2    0
# ...

# %%
op['Fare'] = op[['Fare']].fillna(10)

# %%
op['Fare_new'] = op['Fare'].apply(lambda x : np.log(x) if x>0 else 0)

# %%
op.drop('Name' ,axis=1,inplace=True)

# %%
op.drop(['Title', 'Ticket', 'PassengerId'] ,axis=1,inplace=True)

# %%
op.drop(['Embarked', 'Surnanme'], axis=1,inplace=True)

# %%
op.head()
# Out:
#     Age     Fare  Parch  Pclass  SibSp  Survived  Cabin_letter  title  sex  \
# 0  22.0   7.2500      0       3      1         0             0      0    1
# 1  38.0  71.2833      0       1      1         1             1      1    0
# 2  26.0   7.9250      0       3      0         1             0      2    0
# 3  35.0  53.1000      0       1      1         1             1      1    0
# 4  35.0   8.0500      0       3      0         0             0      0    1
#
#    total_family  SurnameNum  Fare_new
# 0             1           2  1.981001
# 1             1           2  4.266662
# 2             0           1  2.070022
# 3             1           2  3.972177
# 4             0           2  2.085672

# %%
op[op['Fare'] == 0]
# Out:
#       Age  Fare  Parch  Pclass  SibSp  Survived  Cabin_letter  title  sex  \
# 179  36.0   0.0      0       3      0         0             0      0    1
# 263  40.0   0.0      0       1      0         0             6      0    1
# 271  25.0   0.0      0       3      0         1             0      0    1
# 277   NaN   0.0      0       2      0         0             0      0    1
# 302  19.0   0.0      0       3      0         0             0      0    1
# 413   NaN   0.0      0       2      0         0             0      0    1
# 466   NaN   0.0      0       2      0         0             0      0    1
# 481   NaN   0.0      0       2      0         0             0      0    1
# 597  49.0   0.0      0       3      0         0             0      0    1
# 633   NaN   0.0      0       1      0         0             0      0    1
# 674   NaN   0.0      0       2      0         0             0      0    1
# 732   NaN   0.0      0       2      0         0             0      0    1
# ...

# %%
op.to_csv('to_find_age.csv')
